# %% [markdown]
# ## <b> The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market. </b>
#
# ## <b> Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.</b>
#
# ## <b> Explore and analyze the data to discover key factors responsible for app engagement and success. </b>

# %% [markdown]
# **Ratneshwar Kumar individual colab**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as snb
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/ratneshind cap project/Play Store Data.csv')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.head(15)
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                          Paper flowers instructions  ART_AND_DESIGN     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                    Infinite Painter  ART_AND_DESIGN     4.1
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
# ...

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.count()
# Out:
# App               10841
# Category          10841
# Rating             9367
# Reviews           10841
# Size              10841
# Installs          10841
# Type              10840
# Price             10841
# Content Rating    10840
# Genres            10841
# Last Updated      10841
# Current Ver       10833
# Android Ver       10838
# dtype: int64

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df.boxplot()

# %%
df[df.Rating>5]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df.drop([10472],inplace=True)

# %%
df[10468:10474]
# Out:
#                                App         Category  Rating Reviews  Size  \
# 10468             Tassa.fi Finland        LIFESTYLE     3.6     346  7.5M
# 10469  TownWiFi | Wi-Fi Everywhere    COMMUNICATION     3.9    2372   58M
# 10470                   Jazz Wi-Fi    COMMUNICATION     3.4      49  4.0M
# 10471             Xposed Wi-Fi-Pwd  PERSONALIZATION     3.5    1042  404k
# 10473      osmino Wi-Fi: free WiFi            TOOLS     4.2  134203  4.1M
# 10474                 Sat-Fi Voice    COMMUNICATION     3.4      37   14M
#
#           Installs  Type Price Content Rating           Genres  \
# 10468      50,000+  Free     0       Everyone        Lifestyle
# 10469     500,000+  Free     0       Everyone    Communication
# 10470      10,000+  Free     0       Everyone    Communication
# 10471     100,000+  Free     0       Everyone  Personalization
# 10473  10,000,000+  Free     0       Everyone            Tools
# 10474       1,000+  Free     0       Everyone    Communication
#
# ...

# %%
df.boxplot('Rating')

# %%
def replace_median(column):
  return column.fillna(column.median)

# %%
df.Rating = df ['Rating'].transform(replace_median)

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %%
df.describe()
# Out:
#            App Category                                             Rating  \
# count    10840    10840                                              10840
# unique    9659       33                                                 40
# top     ROBLOX   FAMILY  <bound method NDFrame._add_numeric_operations....
# freq         9     1972                                               1474
#
#        Reviews                Size    Installs   Type  Price Content Rating  \
# count    10840               10840       10840  10839  10840          10840
# unique    6001                 461          21      2     92              6
# top          0  Varies with device  1,000,000+   Free      0       Everyone
# freq       596                1695        1579  10039  10040           8714
#
#        Genres    Last Updated         Current Ver Android Ver
# count   10840           10840               10832       10838
# unique    119            1377                2831          33
# ...

# %%
 grp= df.groupby('Category')
 y=grp['Price'].agg(np.sum)
 z=grp['Reviews'].agg(np.mean)
 print(y)
 print(z)
# Out:
# Category
# ART_AND_DESIGN         0000000000000000000000000000000000000000000000...
# AUTO_AND_VEHICLES      0000000000000000000000000000000000000000000000...
# BEAUTY                 0000000000000000000000000000000000000000000000...
# BOOKS_AND_REFERENCE    0000000000000000000000000000000000000000000000...
# BUSINESS               0000000000000000000000000000000000000000000000...
# COMICS                 0000000000000000000000000000000000000000000000...
# COMMUNICATION          0000000000000000000000000000000000000000000000...
# DATING                 $3.99$6.99$1.49$2.99$3.99$7.990000000000000000...
# EDUCATION              0000000000000000000000000000000000000000000000...
# ENTERTAINMENT          0000000000000000000000000000000000000000000000...
# EVENTS                 0000000000000000000000000000000000000000000000...
# FAMILY                 0000000000000000000000000000000000000000000000...
# FINANCE                0000000000000000000000000000000000000000000000...
# ...

# %%
plt.figure(figsize=(16,5))
plt.plot(y,'r--',color='red')
plt.xticks(rotation=90)
plt.title('Category vs Pricing')
plt.xlabel('Categories------------>')
plt.ylabel('Prices------------>')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize=(16,5))
plt.plot(z,'g^',color='green')
plt.xticks(rotation=90)
plt.title('Category vs Reviews')
plt.xlabel('Categories------------>')
plt.ylabel('Reviews------------>')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df.head()
# Out:
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 1                                Coloring book moana  ART_AND_DESIGN    3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN    4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN    4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# # Conclusion

# %% [markdown]
# That's it!
#
# Throughout this COLAB, we put the variables into practise. We analysed 'ratnig' alone and with the most correlated variables. In COLAB, I worked on removing null data and outliers. We tested some of the fundamental statistical assumptions and we even transformed categorial variables into dummy variables. That's a lot of work that Python helped us make easier.
